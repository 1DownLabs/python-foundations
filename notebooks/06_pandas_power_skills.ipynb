# %% [markdown]
# # 06 — Pandas Power Skills (1DownLabs)
#
# Focus:
# - selecting & filtering
# - sorting
# - groupby aggregations
# - joins/merges
# - pivot tables
# - handling missing values
# - building a mini analytics report

# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.append(str(project_root))

import pandas as pd

raw_path = project_root / "data" / "raw" / "vgsales.csv"
df = pd.read_csv(raw_path)

df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Shape of the dataframe
df.shape
# Out:
# (16598, 11)

# %%
# Check Columns
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='str')

# %%
# Check data type of columns

df.dtypes
# Out:
# Rank              int64
# Name                str
# Platform            str
# Year            float64
# Genre               str
# Publisher           str
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Check for null values
df.isna().sum().sort_values(ascending=False)
# Out:
# Year            271
# Publisher        58
# Rank              0
# Platform          0
# Name              0
# Genre             0
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Clean column names
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

df.columns
# Out:
# Index(['rank', 'name', 'platform', 'year', 'genre', 'publisher', 'na_sales',
#        'eu_sales', 'jp_sales', 'other_sales', 'global_sales'],
#       dtype='str')

# %%
# Check the top 10 rows of selected columns ['rank', 'name', 'platform', 'year', 'genre']

df[['rank', 'name', 'platform', 'year', 'genre']].head(10)
# Out:
#    rank                       name platform    year         genre
# 0     1                 Wii Sports      Wii  2006.0        Sports
# 1     2          Super Mario Bros.      NES  1985.0      Platform
# 2     3             Mario Kart Wii      Wii  2008.0        Racing
# 3     4          Wii Sports Resort      Wii  2009.0        Sports
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5     6                     Tetris       GB  1989.0        Puzzle
# 6     7      New Super Mario Bros.       DS  2006.0      Platform
# 7     8                   Wii Play      Wii  2006.0          Misc
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform
# 9    10                  Duck Hunt      NES  1984.0       Shooter

# %%
#  Check top 10 games with global_sales > 2 million

high_sales = df[df['global_sales'] > 2]
high_sales[['name', 'platform', 'year', 'genre', 'publisher', 'global_sales']].sort_values('global_sales',ascending=False).head(10)
# Out:
#                         name platform    year         genre publisher  \
# 0                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    global_sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37
# 5         30.26
# 6         30.01
# 7         29.02
# 8         28.62
# 9         28.31

# %%
# Count number of records > 2 million
high_sales.shape
# Out:
# (846, 11)

# %%
# Sorting + top-N

top_10 = df.sort_values('global_sales', ascending= False)
top_10[['name', 'platform', 'year', 'genre', 'publisher', 'global_sales']].head(10)
# Out:
#                         name platform    year         genre publisher  \
# 0                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    global_sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37
# 5         30.26
# 6         30.01
# 7         29.02
# 8         28.62
# 9         28.31

# %%
# How many missing years?

df['year'].isna().sum()
# Out:
# np.int64(271)

# %%
# Keep only rows with a valid year
df_clean = df.dropna(subset=["year"]).copy()
df_clean["year"] = df_clean["year"].astype(int)
df_clean.shape
# Out:
# (16327, 11)

# %%
# Group by top publishers by global sales

top_publishers = (df_clean.groupby('publisher', as_index=False)
                    .agg(total_sales = ('global_sales', 'sum'),
                    game_count = ('name', 'count'))
                    .sort_values('total_sales', ascending=False)
            )

top_publishers.head(10)
# Out:
#                         publisher  total_sales  game_count
# 359                      Nintendo      1784.43         696
# 138               Electronic Arts      1093.39        1339
# 21                     Activision       721.41         966
# 455   Sony Computer Entertainment       607.28         682
# 524                       Ubisoft       473.54         918
# 493          Take-Two Interactive       399.30         412
# 487                           THQ       340.44         712
# 275  Konami Digital Entertainment       278.56         823
# 445                          Sega       270.70         632
# 347            Namco Bandai Games       253.65         928

# %%
# Multi aggregation by year

yearly_sales = (df_clean.groupby('year', as_index=False)
                    .agg(total_na_sales = ('na_sales', 'sum'),
                    total_eu_sales = ('eu_sales', 'sum'),
                    total_jp_sales = ('jp_sales', 'sum'),
                    total_other_sales = ('other_sales', 'sum'),
                    total_global_sales = ('global_sales', 'sum'))
                    .sort_values('year', ascending=True)
                    )

yearly_sales.head()
# Out:
#    year  total_na_sales  total_eu_sales  total_jp_sales  total_other_sales  \
# 0  1980           10.59            0.67            0.00               0.12
# 1  1981           33.40            1.96            0.00               0.32
# 2  1982           26.92            1.65            0.00               0.31
# 3  1983            7.76            0.80            8.10               0.14
# 4  1984           33.28            2.10           14.27               0.70
#
#    total_global_sales
# 0               11.38
# 1               35.77
# 2               28.86
# 3               16.79
# 4               50.36

# %%
# Pivot Sales : Genre Sales by Year

genre_by_year = pd.pivot_table(
    df_clean,
    index="year",
    columns="genre",
    values="global_sales",
    aggfunc="sum",
    fill_value=0
)

genre_by_year.head()
# Out:
# genre  Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# year
# 1980     0.34        0.0      0.77  2.71      0.00    0.00    0.00
# 1981    14.84        0.0      0.00  0.00      6.93    2.24    0.48
# 1982     6.52        0.0      0.00  0.87      5.03   10.03    1.57
# 1983     2.86        0.4      0.00  2.14      6.93    0.78    0.00
# 1984     1.85        0.0      0.00  1.45      0.69    3.14    5.95
#
# genre  Role-Playing  Shooter  Simulation  Sports  Strategy
# year
# 1980            0.0     7.07        0.00    0.49       0.0
# 1981            0.0    10.04        0.45    0.79       0.0
# 1982            0.0     3.79        0.00    1.05       0.0
# 1983            0.0     0.48        0.00    3.20       0.0
# 1984            0.0    31.10        0.00    6.18       0.0

# %%
# “Top genre each year”

top_genre_each_year = (
    genre_by_year
    .idxmax(axis=1)
    .to_frame("top_genre")
    .join(genre_by_year.max(axis=1).to_frame("top_genre_sales"))
    .reset_index()
)

top_genre_each_year.head()
# Out:
#    year top_genre  top_genre_sales
# 0  1980   Shooter             7.07
# 1  1981    Action            14.84
# 2  1982    Puzzle            10.03
# 3  1983  Platform             6.93
# 4  1984   Shooter            31.10

# %%
# Merge/join
# Let’s create a “publisher tier” table and join it.

publisher_tier = top_publishers.head(20)[["publisher", "total_sales"]].copy()

publisher_tier["tier"] = "Top 20"

publisher_tier
# Out:
#                                   publisher  total_sales    tier
# 359                                Nintendo      1784.43  Top 20
# 138                         Electronic Arts      1093.39  Top 20
# 21                               Activision       721.41  Top 20
# 455             Sony Computer Entertainment       607.28  Top 20
# 524                                 Ubisoft       473.54  Top 20
# 493                    Take-Two Interactive       399.30  Top 20
# 487                                     THQ       340.44  Top 20
# 275            Konami Digital Entertainment       278.56  Top 20
# 445                                    Sega       270.70  Top 20
# 347                      Namco Bandai Games       253.65  Top 20
# 323                  Microsoft Game Studios       245.79  Top 20
# 85                                   Capcom       199.95  Top 20
# 53                                    Atari       146.77  Top 20
# 464                             Square Enix       144.73  Top 20
# 547  Warner Bros. Interactive Entertainment       142.34  Top 20
# 126              Disney Interactive Studios       118.76  Top 20
# 137                       Eidos Interactive        96.75  Top 20
# 288                               LucasArts        84.95  Top 20
# 66                       Bethesda Softworks        81.53  Top 20
# 325                            Midway Games        69.29  Top 20

# %%
df_clean.head()
# Out:
#    rank                      name platform  year         genre publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_clean_merged = df_clean.merge(publisher_tier[["tier","publisher"]], how='left', on='publisher')
# df_clean_merged["tier"] = df_clean_merged["tier"].fillna('Other')
df_clean_merged.head()
# Out:
#    rank                      name platform  year         genre publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales    tier
# 0     41.49     29.02      3.77         8.46         82.74  Top 20
# 1     29.08      3.58      6.81         0.77         40.24  Top 20
# 2     15.85     12.88      3.79         3.31         35.82  Top 20
# 3     15.75     11.01      3.28         2.96         33.00  Top 20
# 4     11.27      8.89     10.22         1.00         31.37  Top 20

# %%
'''Practice 1 — Top 10 platforms by global sales

Output columns:
                platform
                total_global_sales
                game_count'''

top_10_by_global_sales = (df_clean.groupby('platform')
                            .agg(total_global_sales = ("global_sales","sum"),
                            game_count = ("name", "count"))
                            .sort_values('platform', ascending=False))
                            

top_10_by_global_sales = top_10_by_global_sales.sort_values('total_global_sales', ascending=False).head(10)

top_10_by_global_sales
# Out:
#           total_global_sales  game_count
# platform
# PS2                  1233.46        2127
# X360                  969.61        1235
# PS3                   949.35        1304
# Wii                   909.81        1290
# DS                    818.96        2133
# PS                    727.39        1189
# GBA                   313.56         811
# PSP                   291.71        1197
# PS4                   278.10         336
# PC                    255.05         943

# %%
'''Practice 2 — Best selling game per year

For each year, find the game with max global_sales.

Output columns:

year

name

platform

global_sales'''

df_clean['sales_rank'] =  (df_clean.groupby('year')['global_sales'].rank(method='min', ascending=False))

df_clean[df_clean['sales_rank'] == 1].sort_values('year')
# Out:
#         rank                                              name platform  year  \
# 258      259                                         Asteroids     2600  1980
# 239      240                                          Pitfall!     2600  1981
# 89        90                                           Pac-Man     2600  1982
# 421      422                                          Baseball      NES  1983
# 9         10                                         Duck Hunt      NES  1984
# 1          2                                 Super Mario Bros.      NES  1985
# 127      128                               The Legend of Zelda      NES  1986
# 251      252                   Zelda II: The Adventure of Link      NES  1987
# 22        23                               Super Mario Bros. 3      NES  1988
# 5          6                                            Tetris       GB  1989
# 18        19                                 Super Mario World     SNES  1990
# 231      232           The Legend of Zelda: A Link to the Past     SNES  1991
# 50        51                Super Mario Land 2: 6 Golden Coins       GB  1992
# 57        58                             Super Mario All-Stars     SNES  1993
# 71        72                               Donkey Kong Country     SNES  1994
# 187      188         Donkey Kong Country 2: Diddy's Kong Quest     SNES  1995
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# 52        53                                      Gran Turismo       PS  1997
# 30        31           Pokémon Yellow: Special Pikachu Edition       GB  1998
# 12        13                       Pokemon Gold/Pokemon Silver       GB  1999
# 132      133                           Pokémon Crystal Version       GB  2000
# 28        29                            Gran Turismo 3: A-Spec      PS2  2001
# 24        25                       Grand Theft Auto: Vice City      PS2  2002
# 104      105                        Need for Speed Underground      PS2  2003
# 17        18                     Grand Theft Auto: San Andreas      PS2  2004
# 10        11                                        Nintendogs       DS  2005
# 0          1                                        Wii Sports      Wii  2006
# 13        14                                           Wii Fit      Wii  2007
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 15        16                                Kinect Adventures!     X360  2010
# 29        30                    Call of Duty: Modern Warfare 3     X360  2011
# 34        35                        Call of Duty: Black Ops II      PS3  2012
# 16        17                                Grand Theft Auto V      PS3  2013
# 44        45                                Grand Theft Auto V      PS4  2014
# 33        34                         Call of Duty: Black Ops 3      PS4  2015
# 221      222                                           FIFA 17      PS4  2016
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017
# 5957    5959                            Imagine: Makeup Artist       DS  2020
#
#               genre                    publisher  na_sales  eu_sales  \
# 258         Shooter                        Atari      4.00      0.26
# 239        Platform                   Activision      4.21      0.24
# 89           Puzzle                        Atari      7.28      0.45
# 421          Sports                     Nintendo      0.73      0.10
# 9           Shooter                     Nintendo     26.93      0.63
# 1          Platform                     Nintendo     29.08      3.58
# 127          Action                     Nintendo      3.74      0.93
# 251       Adventure                     Nintendo      2.19      0.50
# 22         Platform                     Nintendo      9.54      3.44
# 5            Puzzle                     Nintendo     23.20      2.26
# 18         Platform                     Nintendo     12.78      3.75
# 231          Action                     Nintendo      2.42      0.91
# 50        Adventure                     Nintendo      6.16      2.04
# 57         Platform                     Nintendo      5.99      2.15
# 71         Platform                     Nintendo      4.36      1.71
# 187        Platform                     Nintendo      2.10      0.74
# 4      Role-Playing                     Nintendo     11.27      8.89
# 52           Racing  Sony Computer Entertainment      4.02      3.87
# 30     Role-Playing                     Nintendo      5.89      5.04
# 12     Role-Playing                     Nintendo      9.00      6.18
# 132    Role-Playing                     Nintendo      2.55      1.56
# 28           Racing  Sony Computer Entertainment      6.85      5.09
# 24           Action         Take-Two Interactive      8.41      5.49
# 104          Racing              Electronic Arts      3.27      2.83
# 17           Action         Take-Two Interactive      9.43      0.40
# 10       Simulation                     Nintendo      9.07     11.00
# 0            Sports                     Nintendo     41.49     29.02
# 13           Sports                     Nintendo      8.94      8.03
# 2            Racing                     Nintendo     15.85     12.88
# 3            Sports                     Nintendo     15.75     11.01
# 15             Misc       Microsoft Game Studios     14.97      4.94
# 29          Shooter                   Activision      9.03      4.28
# 34          Shooter                   Activision      4.99      5.88
# 16           Action         Take-Two Interactive      7.01      9.27
# 44           Action         Take-Two Interactive      3.80      5.81
# 33          Shooter                   Activision      5.77      5.81
# 221          Sports              Electronic Arts      0.28      3.75
# 14390  Role-Playing                         Sega      0.00      0.00
# 5957     Simulation                      Ubisoft      0.27      0.00
#
#        jp_sales  other_sales  global_sales  sales_rank
# 258        0.00         0.05          4.31         1.0
# 239        0.00         0.05          4.50         1.0
# 89         0.00         0.08          7.81         1.0
# 421        2.35         0.02          3.20         1.0
# 9          0.28         0.47         28.31         1.0
# 1          6.81         0.77         40.24         1.0
# 127        1.69         0.14          6.51         1.0
# 251        1.61         0.08          4.38         1.0
# 22         3.84         0.46         17.28         1.0
# 5          4.22         0.58         30.26         1.0
# 18         3.54         0.55         20.61         1.0
# 231        1.15         0.13          4.61         1.0
# 50         2.69         0.29         11.18         1.0
# 57         2.12         0.29         10.55         1.0
# 71         3.00         0.23          9.30         1.0
# 187        2.20         0.11          5.15         1.0
# 4         10.22         1.00         31.37         1.0
# 52         2.54         0.52         10.95         1.0
# 30         3.12         0.59         14.64         1.0
# 12         7.20         0.71         23.10         1.0
# 132        1.29         0.99          6.39         1.0
# 28         1.87         1.16         14.98         1.0
# 24         0.47         1.78         16.15         1.0
# 104        0.08         1.02          7.20         1.0
# 17         0.41        10.57         20.81         1.0
# 10         1.93         2.75         24.76         1.0
# 0          3.77         8.46         82.74         1.0
# 13         3.60         2.15         22.72         1.0
# 2          3.79         3.31         35.82         1.0
# 3          3.28         2.96         33.00         1.0
# 15         0.24         1.67         21.82         1.0
# 29         0.13         1.32         14.76         1.0
# 34         0.65         2.52         14.03         1.0
# 16         0.97         4.14         21.40         1.0
# 44         0.36         2.02         11.98         1.0
# 33         0.35         2.31         14.24         1.0
# 221        0.06         0.69          4.77         1.0
# 14390      0.03         0.00          0.03         1.0
# 5957       0.00         0.02          0.29         1.0

# %%
'''Practice 3 — Regional mix

For the top 10 publishers by global sales, compute:
# %NA
# %EU
# %JP
# %Other'''

top_10_publisher = (df_clean.groupby('publisher').agg(total_global_sales = ("global_sales" , "sum"),
                                                        total_na_sales = ("na_sales" , "sum"),
                                                        total_eu_sales = ('eu_sales' , 'sum'),
                                                        total_jp_sales = ('jp_sales', 'sum'),
                                                        total_other_sales = ('other_sales', 'sum'))
                                                .sort_values('total_global_sales', ascending=False).head(10))
top_10_publisher
# Out:
#                               total_global_sales  total_na_sales  \
# publisher
# Nintendo                                 1784.43          815.75
# Electronic Arts                          1093.39          584.22
# Activision                                721.41          426.01
# Sony Computer Entertainment               607.28          265.22
# Ubisoft                                   473.54          252.81
# Take-Two Interactive                      399.30          220.47
# THQ                                       340.44          208.60
# Konami Digital Entertainment              278.56           88.91
# Sega                                      270.70          108.78
# Namco Bandai Games                        253.65           69.38
#
#                               total_eu_sales  total_jp_sales  \
# publisher
# Nintendo                              418.30          454.99
# Electronic Arts                       367.38           13.98
# Activision                            213.72            6.54
# Sony Computer Entertainment           187.55           74.10
# Ubisoft                               163.03            7.33
# Take-Two Interactive                  117.95            5.83
# THQ                                    94.60            5.01
# Konami Digital Entertainment           68.62           90.93
# Sega                                   81.41           56.19
# Namco Bandai Games                     42.61          126.84
#
#                               total_other_sales
# publisher
# Nintendo                                  95.19
# Electronic Arts                          127.63
# Activision                                74.79
# Sony Computer Entertainment               80.40
# Ubisoft                                   50.16
# Take-Two Interactive                      55.20
# THQ                                       32.11
# Konami Digital Entertainment              29.91
# Sega                                      24.30
# Namco Bandai Games                        14.64

# %%
top_10_publisher['%_NA'] = top_10_publisher['total_na_sales'] / top_10_publisher['total_global_sales'] 
top_10_publisher['%_EU'] = top_10_publisher['total_eu_sales'] / top_10_publisher['total_global_sales'] 
top_10_publisher['%_JP'] = top_10_publisher['total_jp_sales'] / top_10_publisher['total_global_sales'] 
top_10_publisher['%_Other'] = top_10_publisher['total_other_sales'] / top_10_publisher['total_global_sales'] 

top_10_publisher = top_10_publisher.reset_index()[['publisher' ,'%_NA', '%_EU', '%_Other', '%_JP']]

# %%
top_10_publisher
# Out:
#                       publisher      %_NA      %_EU   %_Other      %_JP
# 0                      Nintendo  0.457149  0.234417  0.053345  0.254978
# 1               Electronic Arts  0.534320  0.336001  0.116729  0.012786
# 2                    Activision  0.590524  0.296253  0.103672  0.009066
# 3   Sony Computer Entertainment  0.436734  0.308836  0.132394  0.122019
# 4                       Ubisoft  0.533873  0.344279  0.105926  0.015479
# 5          Take-Two Interactive  0.552141  0.295392  0.138242  0.014601
# 6                           THQ  0.612736  0.277876  0.094319  0.014716
# 7  Konami Digital Entertainment  0.319177  0.246338  0.107374  0.326429
# 8                          Sega  0.401847  0.300739  0.089767  0.207573
# 9            Namco Bandai Games  0.273527  0.167987  0.057717  0.500059

# %% [markdown]
# ## Summary
#
# This notebook covered core Pandas skills:
# - filtering, sorting, and selecting columns
# - groupby aggregations and multi-metrics
# - pivot tables and derived insights
# - merges/joins
# - saving processed outputs + writing reports
